# %% [markdown]
# # Loading Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns
import os

# %% [markdown]
# # Preparing data for vector embeddings

# %%
base_dir = os.path.join('..', 'data')
tmdb_df = pd.read_csv(base_dir+'/processed_data/tmdb_content_processed.csv')

# %%
tmdb_df.head()
# Out:
#              title release_date     revenue  runtime  imdb_id  \
# 0        Inception   2010-07-15   825532764      148  1375666
# 1     Interstellar   2014-11-05   701729206      169   816692
# 2  The Dark Knight   2008-07-16  1004558444      152   468569
# 3           Avatar   2009-12-15  2923706026      162   499549
# 4     The Avengers   2012-04-25  1518815515      143   848228
#
#   original_language                                           overview  \
# 0           English  Cobb, a skilled thief who commits corporate es...
# 1           English  The adventures of a group of explorers who mak...
# 2           English  Batman raises the stakes in his war on crime. ...
# 3           English  In the 22nd century, a paraplegic Marine is di...
# 4           English  When an unexpected enemy emerges and threatens...
#
#                                 production_companies  \
# 0  Legendary Pictures, Syncopy, Warner Bros. Pict...
# 1  Legendary Pictures, Syncopy, Lynda Obst Produc...
# 2  DC Comics, Legendary Pictures, Syncopy, Isobel...
# 3  Dune Entertainment, Lightstorm Entertainment, ...
# 4                                     Marvel Studios
#
#                      spoken_languages  \
# 0  English, French, Japanese, Swahili
# 1                             English
# 2                   English, Mandarin
# 3                    English, Spanish
# 4             English, Hindi, Russian
#
#                                         plot_summary  \
# 0  Dom Cobb is a skilled thief, the absolute best...
# 1  In the near future around the American Midwest...
# 2  Set within a year after the events of Batman B...
# 3  When his brother is killed in a robbery, parap...
# 4  Loki, the adopted brother of Thor, teams-up wi...
#
#                                        plot_synopsis  \
# 0  Dominick "Dom" Cobb (Leonardo DiCaprio) and bu...
# 1  In the future, crop blight has caused civiliza...
# 2  A gang of 6 criminals rob a Gotham City mob ba...
# 3  In 2154, humans have depleted Earth's natural ...
# 4  The Asgardian Loki (Tom Hiddleston) encounters...
#
#                                 genres  \
# 0  Action, Adventure, Sci-Fi, Thriller
# 1             Adventure, Drama, Sci-Fi
# 2       Action, Crime, Drama, Thriller
# 3   Action, Adventure, Fantasy, Sci-Fi
# 4                       Action, Sci-Fi
#
#                                                 cast          directors  \
# 0  Leonardo DiCaprio, Joseph Gordon-Levitt, Ellio...  Christopher Nolan
# 1  Ellen Burstyn, Matthew McConaughey, Mackenzie ...  Christopher Nolan
# 2  Christian Bale, Heath Ledger, Aaron Eckhart, M...  Christopher Nolan
# 3  Sam Worthington, Zoe Saldaña, Sigourney Weaver...      James Cameron
# 4  Robert Downey Jr., Chris Evans, Mark Ruffalo, ...        Joss Whedon
#
#    averageRating  numVotes  release_year  release_month  release_day
# 0            8.8   2681459          2010              7           15
# 1            8.7   2342692          2014             11            5
# 2            9.0   3018672          2008              7           16
# 3            7.9   1430332          2009             12           15
# 4            8.0   1507612          2012              4           25

# %% [markdown]
# Data Analysis

# %%
# Count movies per original language and sort in descending order
language_counts = tmdb_df['original_language'].value_counts()

# Get top 10 languages
top_10_languages = language_counts.head(10)


# Display counts
print("\nTop 10 languages by number of movies:")
print(top_10_languages)
# Out:
# Top 10 languages by number of movies:
# original_language
# English     7904
# Hindi        672
# French       403
# Japanese     234
# Spanish      228
# Tamil        163
# Korean       162
# Chinese      144
# German       131
# Telugu       102
# Name: count, dtype: int64

# %% [markdown]
# Creating dataset for content based recommendation

# %%
df_temp = tmdb_df[['imdb_id', 'title', 'release_date', 'plot_synopsis', 'genres', 'cast', 'directors']].copy()

# %%
df_temp[['genres', 'cast', 'directors']] = df_temp[['genres', 'cast', 'directors']].apply(lambda col: col.str.replace(r'(?<=\w)\s+(?=\w)', '', regex=True))

# %%
# Combine the columns into a single column called 'wordsoup', limiting cast to top 10
df_temp['wordsoup'] = df_temp['plot_synopsis'] + ' ' + df_temp['genres'] + ' ' + df_temp['cast'].apply(lambda x: ', '.join(x.split(',')[:10])) + ' ' + df_temp['directors']

# %%
df_temp.head()
# Out:
#    imdb_id            title release_date  \
# 0  1375666        Inception   2010-07-15
# 1   816692     Interstellar   2014-11-05
# 2   468569  The Dark Knight   2008-07-16
# 3   499549           Avatar   2009-12-15
# 4   848228     The Avengers   2012-04-25
#
#                                        plot_synopsis  \
# 0  Dominick "Dom" Cobb (Leonardo DiCaprio) and bu...
# 1  In the future, crop blight has caused civiliza...
# 2  A gang of 6 criminals rob a Gotham City mob ba...
# 3  In 2154, humans have depleted Earth's natural ...
# 4  The Asgardian Loki (Tom Hiddleston) encounters...
#
#                                 genres  \
# 0  Action, Adventure, Sci-Fi, Thriller
# 1             Adventure, Drama, Sci-Fi
# 2       Action, Crime, Drama, Thriller
# 3   Action, Adventure, Fantasy, Sci-Fi
# 4                       Action, Sci-Fi
#
#                                                 cast         directors  \
# 0  LeonardoDiCaprio, JosephGordon-Levitt, ElliotP...  ChristopherNolan
# 1  EllenBurstyn, MatthewMcConaughey, MackenzieFoy...  ChristopherNolan
# 2  ChristianBale, HeathLedger, AaronEckhart, Mich...  ChristopherNolan
# 3  SamWorthington, ZoeSaldaña, SigourneyWeaver, S...      JamesCameron
# 4  RobertDowneyJr., ChrisEvans, MarkRuffalo, Chri...        JossWhedon
#
#                                             wordsoup
# 0  Dominick "Dom" Cobb (Leonardo DiCaprio) and bu...
# 1  In the future, crop blight has caused civiliza...
# 2  A gang of 6 criminals rob a Gotham City mob ba...
# 3  In 2154, humans have depleted Earth's natural ...
# 4  The Asgardian Loki (Tom Hiddleston) encounters...

# %%
# Convert to lowercase and remove extra spaces
df_temp['wordsoup'] = df_temp['wordsoup'].str.lower().str.strip().replace(r'\s+', ' ', regex=True)

# Display the updated DataFrame
df_temp[['wordsoup']].head()
# Out:
#                                             wordsoup
# 0  dominick "dom" cobb (leonardo dicaprio) and bu...
# 1  in the future, crop blight has caused civiliza...
# 2  a gang of 6 criminals rob a gotham city mob ba...
# 3  in 2154, humans have depleted earth's natural ...
# 4  the asgardian loki (tom hiddleston) encounters...

# %%
final_df = df_temp[['imdb_id', 'title', 'wordsoup']].copy()
final_df.head()
# Out:
#    imdb_id            title                                           wordsoup
# 0  1375666        Inception  dominick "dom" cobb (leonardo dicaprio) and bu...
# 1   816692     Interstellar  in the future, crop blight has caused civiliza...
# 2   468569  The Dark Knight  a gang of 6 criminals rob a gotham city mob ba...
# 3   499549           Avatar  in 2154, humans have depleted earth's natural ...
# 4   848228     The Avengers  the asgardian loki (tom hiddleston) encounters...

# %%
# Remove commas and special characters from the 'wordsoup' column
final_df['wordsoup'] = final_df['wordsoup'].str.replace(r'[^A-Za-z0-9\s]', '', regex=True)

# Display the updated DataFrame
final_df[['wordsoup']].head()
